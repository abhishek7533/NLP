# 4                முலாயம் சிங் மருத்துவமனையில் அனுமதி
#
#                                                 link  \
# 0  https://www.newspointapp.com/odia-news/publish...
# 1  https://navbharattimes.indiatimes.com/metro/lu...
# 2  https://maharashtratimes.indiatimes.com/citize...
# 3  https://www.newspointapp.com/english-news/publ...
# 4  https://www.seithisolai.com/mulayam-singh-admi...
#
#                                          description  \
# 0  କନକ ବ୍ୟୁରୋ : ଜାଡରେ ଥରୁଛି ସାରା ଓଡିଶା । ସ୍ୱାଭାବି...
# 1  \Bसंदीपन ने कलाकारों को दिशा देने के साथ नाट्य...
# 2                                                NaN
# 3  BHOPAL: The widespread protests against CAA ar...
# 4  சமாஜ்வாதி கட்சியின் நிறுவனத் தலைவர் முலாயம் சி...
#
#                                     long_description      id
# 0  କନକ ବ୍ୟୁରୋ : ଜାଡରେ ଥରୁଛି ସାରା ଓଡିଶା । ସ୍ୱାଭାବି...  2674.0
# 1  B Sandipan awakened the play with consciousnes...  3874.0
# 2                                                NaN   425.0
# 3  BHOPAL: The widespread protests against CAA ar...  5177.0
# 4  Samajwadi Party founder Mulayam Singh has been...  3260.0

# %%
df['word_count'] = df['title'].apply(lambda x: len(str(x).split(" ")))

# %%
df[['title','word_count']].head(5)
# Out:
#                                                title  word_count
# 0  ପ୍ରବଳ ଶୀତରେ ଥରୁଛି ସାରା ଓଡ଼ିଶା । ୧୩ଟି ଜିଲ୍ଲା ପାଇ...          20
# 1  'संघर्षशील और जुझारू संस्कृतिकर्मी थे संदीपन व...           8
# 2                                      डीपी रामभरोसे           2
# 3  Whipping up nationalism has a shelf life: Kama...           9
# 4                முலாயம் சிங் மருத்துவமனையில் அனுமதி           4

# %%
df.word_count.describe()
# Out:
# count    1.408876e+06
# mean     1.016067e+01
# std      6.572430e+00
# min      1.000000e+00
# 25%      7.000000e+00
# 50%      1.000000e+01
# 75%      1.200000e+01
# max      2.953000e+03
# Name: word_count, dtype: float64

# %%
freq = pd.Series(' '.join(df['title']).split()).value_counts()[:100]
freq
# Out:
# के      132409
# to      126541
# में     119748
# in      107036
# की      101914
#          ...
# हुआ       6312
# क्या      6303
# may       6201
# अब        6041
# ।         5990
# Length: 100, dtype: int64

# %%
freq1 =  pd.Series(' '.join(df['title']).split()).value_counts()[-20:]
freq1
# Out:
# વાસ્તુટિપ્સ:                                                                                                                                                            1
# চেকবই                                                                                                                                                                   1
# Days!-                                                                                                                                                                  1
# ഭര്‍ത്താവിനുണ്ടായ                                                                                                                                                       1
# அஞ்சனாவை                                                                                                                                                                1
# भरनी-                                                                                                                                                                   1
# વઘારાલી                                                                                                                                                                 1
# വനത്തിനുള്ളിലെ                                                                                                                                                          1
# STCG                                                                                                                                                                    1
# ट्रिप|https://navbharattimes.indiatimes.com/business/business-news/auto-expo-top-chinese-executives-canceled-trips-due-to-corona-virus/articleshow/73911929.cms|केतन    1
# देवाडिगाला                                                                                                                                                              1
# തലകുനിക്കാതെ                                                                                                                                                            1
# वाॅट्सएप                                                                                                                                                                1
# ക്ഷ​മാ​പ​ണം                                                                                                                                                             1
# சுயதொழில்...                                                                                                                                                            1
# चालणाऱ्या                                                                                                                                                               1
# தங்கபாண்டியன்..!                                                                                                                                                        1
# ಠಕ್ಕರ್                                                                                                                                                                  1
# ରେକଡ୍ଡ                                                                                                                                                                  1
# 'Minnale'                                                                                                                                                               1
# dtype: int64

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import RegexpTokenizer
from nltk.stem.wordnet import WordNetLemmatizer

# %% [markdown]
# # Stop word for english

# %%
stop_words = set(stopwords.words("english"))

# %% [markdown]
# # Add a Stop words

# %%
#new_words = ["using", "show", "result", "large", "also", "one", "two", "new", "previously", "shown"]
#stop_words = stop_words.union(new_words)

# %%
corpus = []
for i in range(0, 1408875):
    #Remove punctuations
    text = re.sub('[^a-zA-Z]', ' ', df['title'][i])
    
    #Convert to lowercase
    text = text.lower()
    
    #remove tags
    text=re.sub("lt&;/?.*?&gt;"," &lt;&gt; ",text)
    
    # remove special characters and digits
    text=re.sub("(\\d|\\W)+"," ",text)
    
    ##Convert to list from string
    text = text.split()
    
    ##Stemming
    ps=PorterStemmer()
    #Lemmatisation
    lem = WordNetLemmatizer()
    text = [lem.lemmatize(word) for word in text if not word in  
            stop_words] 
    text = " ".join(text)
    corpus.append(text)

# %%
corpus[1408874]
# Out:
# 'toll coronavirus rise italy'

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
# %matplotlib inline
wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stop_words,
                          max_words=100,
                          max_font_size=50, 
                          random_state=42
                         ).generate(str(corpus))
print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
fig.savefig("word1.png", dpi=900)
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x000001DBD8F27288>

# %%
from sklearn.feature_extraction.text import CountVectorizer
import re
cv=CountVectorizer(max_df=0.8,stop_words=stop_words, max_features=10000, ngram_range=(1,3))
X=cv.fit_transform(corpus)

# %%
list(cv.vocabulary_.keys())
# Out:
# ['nationalism',
#  'life',
#  'kamal',
#  'nath',
#  'kamal nath',
#  'kid',
#  'story',
#  'nursery',
#  'rhyme',
#  'baby',
#  'song',
#  'krishna',
#  'sri',
#  'tamil',
#  'kid story',
#  'story nursery',
#  'nursery rhyme',
#  'rhyme baby',
#  'baby song',
#  'kid nursery',
#  'nursery story',
#  'story tamil',
#  'kid story nursery',
#  'story nursery rhyme',
#  'nursery rhyme baby',
#  'rhyme baby song',
#  'kid nursery story',
#  'nursery story tamil',
#  'tottenham',
#  'willing',
#  'offer',
#  'christian',
#  'eriksen',
#  'real',
#  'madrid',
#  'swap',
#  'deal',
#  'epl',
#  'transfer',
#  'news',
#  'roundup',
#  'th',
#  'december',
#  'real madrid',
#  'transfer news',
#  'news roundup',
#  'roundup th',
#  'transfer news roundup',
#  'news roundup th',
#  'reliance',
#  'gb',
#  'winter',
#  'chill',
#  'grip',
#  'north',
#  'india',
#  'dal',
#  'lake',
#  'begin',
#  'freeze',
#  'north india',
#  'farhan',
#  'akhtar',
#  'town',
#  'mourns',
#  'kushal',
#  'punjabi',
#  'death',
#  'farhan akhtar',
#  'kushal punjabi',
#  'question',
#  'vital',
#  'economy',
#  'business',
#  'politics',
#  'technology',
#  'family',
#  'finance',
#  'primary',
#  'financial',
#  'goal',
#  'achieve',
#  'ease',
#  'mumbai',
#  'cop',
#  'stop',
#  'bicycle',
#  'thief',
#  'save',
#  'day',
#  'son',
#  'received',
#  'gift',
#  'mumbai cop',
#  'recruitment',
#  'scam',
#  'candidate',
#  'booked',
#  'getting',
#  'write',
#  'exam',
#  'amazon',
#  'app',
#  'quiz',
#  'amazon app',
#  'app quiz',
#  'amazon app quiz',
#  'pakistani',
#  'fighting',
#  'back',
#  'demand',
#  'like',
#  'year',
#  'indian',
#  'tech',
#  'startup',
#  'full',
#  'meal',
#  'market',
#  'caa',
#  'nrc',
#  'caa nrc',
#  'salman',
#  'clean',
#  'wash',
#  'volkswagen',
#  'sell',
#  'vehicle',
#  'kriti',
#  'pen',
#  'sweet',
#  'birthday',
#  'wish',
#  'birthday wish',
#  'jio',
#  'bangladesh',
#  'former',
#  'foreign',
#  'secretary',
#  'ali',
#  'dy',
#  'express',
#  'grief',
#  'maharashtra',
#  'time',
#  'maharashtra time',
#  'hong',
#  'kong',
#  'stock',
#  'close',
#  'month',
#  'high',
#  'hong kong',
#  'month high',
#  'dangerous',
#  'fort',
#  'one',
#  'want',
#  'stay',
#  'sun',
#  'set',
#  'view',
#  'retreat',
#  'negative',
#  'rate',
#  'clear',
#  'investor',
#  'pmc',
#  'bank',
#  'page',
#  'charge',
#  'sheet',
#  'filed',
#  'accused',
#  'pmc bank',
#  'end',
#  'boycott',
#  'threat',
#  'compete',
#  'without',
#  'buyer',
#  'air',
#  'might',
#  'forced',
#  'shut',
#  'six',
#  'airline',
#  'official',
#  'air india',
#  'six month',
#  'gym',
#  'new',
#  'resolution',
#  'map',
#  'land',
#  'value',
#  'lakh',
#  'village',
#  'ensure',
#  'cm',
#  'police',
#  'maharashtra cm',
#  'govt',
#  'go',
#  'ahead',
#  'implementation',
#  'kishan',
#  'reddy',
#  'go ahead',
#  'kishan reddy',
#  'raveena',
#  'tandon',
#  'farah',
#  'khan',
#  'bharti',
#  'singh',
#  'slapped',
#  'second',
#  'fir',
#  'punjab',
#  'hurting',
#  'religious',
#  'sentiment',
#  'raveena tandon',
#  'farah khan',
#  'bharti singh',
#  'walk',
#  'talk',
#  'kunal',
#  'kemmu',
#  'share',
#  'pretty',
#  'picture',
#  'wifey',
#  'soha',
#  'take',
#  'street',
#  'sydney',
#  'kunal kemmu',
#  'ali khan',
#  'uddhav',
#  'thackeray',
#  'others',
#  'ajit',
#  'pawar',
#  'sworn',
#  'deputy',
#  'uddhav thackeray',
#  'ajit pawar',
#  'deputy cm',
#  'himanshi',
#  'khurana',
#  'look',
#  'cute',
#  'himanshi khurana',
#  'craft',
#  'plastic',
#  'say',
#  'radhika',
#  'royal',
#  'watch',
#  'live',
#  'streaming',
#  'detail',
#  'premier',
#  'league',
#  'live streaming',
#  'streaming detail',
#  'premier league',
#  'live streaming detail',
#  'natural',
#  'born',
#  'citizen',
#  'become',
#  'president',
#  'vp',
#  'prime',
#  'minister',
#  'prime minister',
#  'bihar',
#  'asks',
#  'promote',
#  'wood',
#  'paper',
#  'industry',
#  'bihar cm',
#  'remake',
#  'bollywood',
#  'film',
#  'kiara',
#  'advani',
#  'would',
#  'part',
#  'kiara advani',
#  'sport',
#  'macro',
#  'uncertainty',
#  'chandra',
#  'crime',
#  'aaditya',
#  'cabinet',
#  'dy cm',
#  'kangana',
#  'dedicates',
#  'panga',
#  'mom',
#  'nadu',
#  'school',
#  'reopen',
#  'january',
#  'tamil nadu',
#  'organic',
#  'growth',
#  'driver',
#  'next',
#  'next year',
#  'killed',
#  'construction',
#  'tunnel',
#  'china',
#  'jac',
#  'class',
#  'admit',
#  'card',
#  'admit card',
#  'woman',
#  'elephant',
#  'attack',
#  'odisha',
#  'thousand',
#  'trapped',
#  'australia',
#  'beach',
#  'fire',
#  'rajamouli',
#  'interview',
#  'update',
#  'psu',
#  'slip',
#  'bob',
#  'share market',
#  'market update',
#  'update psu',
#  'psu bank',
#  'bank share',
#  'share slip',
#  'share market update',
#  'market update psu',
#  'himachal',
#  'pradesh',
#  'top',
#  'sq',
#  'km',
#  'forest',
#  'surge',
#  'himachal pradesh',
#  'india top',
#  'mouni',
#  'roy',
#  'stunning',
#  'dubai',
#  'vacation',
#  'mouni roy',
#  'look stunning',
#  'share picture',
#  'recover',
#  'gavaskar',
#  'bandra',
#  'plot',
#  'dedicated',
#  'centre',
#  'aadhaar',
#  'hubballi',
#  'first',
#  'karnataka',
#  'rise',
#  'pune',
#  'cover',
#  'yr',
#  'talent',
#  'search',
#  'shanghai',
#  'event',
#  'aap',
#  'aditya',
#  'wicket',
#  'match',
#  'haul',
#  'script',
#  'come',
#  'behind',
#  'win',
#  'vidarbha',
#  'rajasthan',
#  'sanjay',
#  'manjrekar',
#  'ravindra',
#  'jadeja',
#  'sanjay manjrekar',
#  'ravindra jadeja',
#  'railway',
#  'given',
#  'mw',
#  'solar',
#  'power',
#  'plant',
#  'meet',
#  'need',
#  'solar power',
#  'power plant',
#  'actress',
#  'play',
#  'malala',
#  'role',
#  'glamorous',
#  'real life',
#  'held',
#  'heritage',
#  'mcx',
#  'oil',
#  'likely',
#  'move',
#  'range',
#  'tough',
#  'pakistan',
#  'test',
#  'raw',
#  'el',
#  'nirmala',
#  'sitharaman',
#  'announces',
#  'crore',
#  'spent',
#  'national',
#  'infrastructure',
#  'project',
#  'finance minister',
#  'nirmala sitharaman',
#  'lakh crore',
#  'judge',
#  'neha',
#  'dhupia',
#  'faced',
#  'south',
#  'cinema',
#  'revealed',
#  'neha dhupia',
#  'bigg',
#  'bos',
#  'kannada',
#  'priyanka',
#  'became',
#  'captain',
#  'bb',
#  'house',
#  'deepika',
#  'da',
#  'get',
#  'emotional',
#  'bigg bos',
#  'get emotional',
#  'country',
#  'burning',
#  'working',
#  'film industry',
#  'student',
#  'wall',
#  'garden',
#  'peer',
#  'vi',
#  'tu',
#  'version',
#  'anushka',
#  'sharma',
#  'virat',
#  'kohli',
#  'wedding',
#  'finally',
#  'anushka sharma',
#  'sharma virat',
#  'virat kohli',
#  'anushka sharma virat',
#  'sharma virat kohli',
#  'twitter',
#  'reaction',
#  'rashid',
#  'light',
#  'adelaide',
#  'eve',
#  'thunder',
#  'snatch',
#  'victory',
#  'jaw',
#  'defeat',
#  'twitter reaction',
#  'new year',
#  'year eve',
#  'new year eve',
#  'amu',
#  'vc',
#  'regret',
#  'dec',
#  'night',
#  'action',
#  'varsity',
#  'seek',
#  'safety',
#  'police action',
#  'music',
#  'video',
#  'review',
#  'capture',
#  'france',
#  'music video',
#  'four',
#  'world',
#  'champion',
#  'opponent',
#  'pressure',
#  'rawat',
#  'time world',
#  'world champion',
#  'time world champion',
#  'manali',
#  'reel',
#  'sub',
#  'zero',
#  'temperature',
#  'arhaan',
#  'sidharth',
#  'hit',
#  'rashami',
#  'fight',
#  'arhaan khan',
#  'divisive',
#  'amarinder',
#  'amarinder singh',
#  'india news',
#  'ipl',
#  'spot',
#  'fixing',
#  'raja',
#  'ranji',
#  'team',
#  'gujarati',
#  'learn',
#  'make',
#  'box',
#  'learning',
#  'acb',
#  'kapoor',
#  'sir',
#  'biggest',
#  'fest',
#  'green',
#  'state',
#  'still',
#  'deficit',
#  'buy',
#  'idea',
#  'expert',
#  'wednesday',
#  'buy sell',
#  'sell idea',
#  'idea expert',
#  'buy sell idea',
#  'sell idea expert',
#  'package',
#  'university',
#  'harsh',
#  'swiggy',
#  'ceo',
#  'healthy',
#  'starrer',
#  'doctor',
#  'introduce',
#  'marvel',
#  'character',
#  'company',
#  'export',
#  'scheme',
#  'extended',
#  'released',
#  'ac',
#  'card released',
#  'admit card released',
#  'iran',
#  'japan',
#  'leader',
#  'amid',
#  'nuclear',
#  'tatas',
#  'urgent',
#  'relief',
#  'tc',
#  'board',
#  'meeting',
#  'board meeting',
#  'carlos',
#  'ghosn',
#  'escape',
#  'theory',
#  'jet',
#  'aid',
#  'carlos ghosn',
#  'cd',
#  'msme',
#  'two',
#  'truck',
#  'tractor',
#  'catch',
#  'collision',
#  'two killed',
#  'catch fire',
#  'celebration',
#  'year celebration',
#  'new year celebration',
#  'chandigarh',
#  'man',
#  'wife',
#  'man held',
#  'end life',
#  'ban',
#  'toxic',
#  'cream',
#  'cr',
#  'investment',
#  'hold',
#  'fame',
#  'ii',
#  'failed',
#  'deliver',
#  'hero',
#  'electric',
#  'navbharat',
#  'photogallery',
#  'navbharat time',
#  'time photogallery',
#  'navbharat time photogallery',
#  'mohanlal',
#  'looking',
#  'every',
#  'bit',
#  'commander',
#  'first look',
#  'kerala',
#  'assembly',
#  'pinarayi',
#  'vijayan',
#  'criticism',
#  'caa resolution',
#  'pinarayi vijayan',
#  'photo',
#  'sonam',
#  'ahuja',
#  'malaika',
#  'arora',
#  'celebs',
#  'welcome',
#  'kiss',
#  'sonam kapoor',
#  'malaika arora',
#  'town celebs',
#  'gear',
#  'au',
#  'nz',
#  'order',
#  'soldier',
#  'area',
#  'work',
#  'completed',
#  'soon',
#  'current',
#  'wwe',
#  'star',
#  'recently',
#  'announced',
#  'engagement',
#  'wwe star',
#  'latest',
#  'ji',
#  'sung',
#  'latest punjabi',
#  'punjabi song',
#  'latest punjabi song',
#  'bsy',
#  'gf',
#  'gst',
#  'may',
#  'reserve',
#  'job',
#  'amp',
#  'local',
#  'govt may',
#  'help',
#  'transform',
#  'international',
#  'economic',
#  'relation',
#  'start',
#  'price',
#  'time top',
#  'india start',
#  'oil price',
#  'secunderabad',
#  'bottom',
#  'swachh',
#  'ranking',
#  'hyderabad',
#  'hyderabad news',
#  'answer',
#  'five',
#  'pay',
#  'balance',
#  'quiz january',
#  'january get',
#  'get answer',
#  'answer five',
#  'five question',
#  'question win',
#  'win amazon',
#  'amazon pay',
#  'pay balance',
#  'app quiz january',
#  'quiz january get',
#  'january get answer',
#  'get answer five',
#  'answer five question',
#  'five question win',
#  'question win amazon',
#  'win amazon pay',
#  'amazon pay balance',
#  'ssp',
#  'nirbhaya',
#  'sensex',
#  'gain',
#  'point',
#  'nifty',
#  'firm',
#  'global',
#  'cue',
#  'point nifty',
#  'global cue',
#  'makar',
#  'sankranti',
#  'makar sankranti',
#  'fb',
#  'midcap',
#  'turn',
#  'sunil',
#  'mf',
#  'siddhant',
#  'give',
#  'hard',
#  'reply',
#  'ananya',
#  'anti',
#  'protester',
#  'arrested',
#  'anti caa',
#  'caa protester',
#  'anti caa protester',
#  'european',
#  'cheer',
#  'policy',
#  'easing',
#  'trade',
#  'progress',
#  'haryana',
#  'see',
#  'mercury',
#  'punjab haryana',
#  'rd',
#  'zealand',
#  'sweat',
#  'ailing',
#  'williamson',
#  'rd test',
#  'test new',
#  'new zealand',
#  'test new zealand',
#  'target',
#  'bothra',
#  'price target',
#  'target kunal',
#  'kunal bothra',
#  'price target kunal',
#  'target kunal bothra',
#  'bhojpuri',
#  'gana',
#  'jaan',
#  'na',
#  'ft',
#  'tanushree',
#  'bhojpuri gana',
#  'gana video',
#  'video song',
#  'song latest',
#  'latest bhojpuri',
#  'bhojpuri song',
#  'bhojpuri gana video',
#  'gana video song',
#  'song latest bhojpuri',
#  'latest bhojpuri song',
#  'ashok',
#  'leyland',
#  'sale',
#  'per',
#  'cent',
#  'unit',
#  'ashok leyland',
#  'per cent',
#  'delhi',
#  'metro',
#  'launch',
#  'free',
#  'wi',
#  'fi',
#  'airport',
#  'line',
#  'delhi metro',
#  'wi fi',
#  'mining',
#  'gujarat',
#  'development',
#  'climb',
#  'stock gain',
#  'xiaomi',
#  'invest',
#  'billion',
#  'ai',
#  'iot',
#  'calling',
#  'faiz',
#  'hindu',
#  'javed',
#  'javed akhtar',
#  'protest',
#  'calendar',
#  'rally',
#  'planned',
#  'week',
#  'caa protest',
#  'anti caa protest',
#  'race',
#  'heat',
#  'pete',
#  'buttigieg',
#  'step',
#  'mayor',
#  'singer',
#  'performs',
#  'noida',
#  'cricket',
#  'schedule',
#  'stadium',
#  'venue',
#  'date',
#  'international cricket',
#  'ip',
#  'higher',
#  'optimism',
#  'middle',
#  'east',
#  'tension',
#  'start new',
#  'middle east',
#  'yo',
#  'honey',
#  'made',
#  'special',
#  'fan',
#  'performance',
#  'america',
#  'connection',
#  'murder',
#  'mahesh',
#  'bhatt',
#  'swara',
#  'bhasker',
#  'join',
#  'release',
#  'mahesh bhatt',
#  'swara bhasker',
#  'padukone',
#  'reveals',
#  'ranveer',
#  'pant',
#  'stage',
#  'concert',
#  'deepika padukone',
#  'ranveer singh',
#  'jasprit',
#  'bumrah',
#  'jasprit bumrah',
#  'case',
#  'transferred',
#  'branch',
#  'crime branch',
#  'delhi police',
#  'lead',
#  'leg',
#  'shibani',
#  'kota',
#  'flood',
#  'indonesia',
#  'capital',
#  'toll',
#  'reach',
#  'death toll',
#  'toll reach',
#  'led',
#  'capable',
#  'winning',
#  'icc',
#  'tournament',
#  'lara',
#  'cwc',
#  'punk',
#  'knocked',
#  'michael',
#  'bizarre',
#  'cm punk',
#  'wrestle',
#  'prediction',
#  'approves',
#  'home',
#  'vaccine',
#  'offering',
#  'alternative',
#  'product',
#  'sa',
#  'eng',
#  'sa eng',
#  'past',
#  'decade',
#  'easier',
#  'actor',
#  'opportunity',
#  'england',
#  'burn',
#  'archer',
#  'skip',
#  'training',
#  'austria',
#  'government',
#  'carbon',
#  'neutral',
#  'shimla',
#  'movie',
#  'rajkummar',
#  'rao',
#  'rakul',
#  'preet',
#  'headache',
#  'movie review',
#  'rajkummar rao',
#  'rakul preet',
#  'preet singh',
#  'rakul preet singh',
#  'bound',
#  'protect',
#  'minority',
#  'pm',
#  'modi',
#  'say pm',
#  'pm modi',
#  'say pm modi',
#  'steel',
#  'auto',
#  'infra',
#  'may rise',
#  'isl',
#  'vacancy',
#  'iti',
#  'non',
#  'aspirant',
#  'apply',
#  'corporation',
#  'plan',
#  'annual',
#  'fair',
#  'small',
#  'ramlila',
#  'maidan',
#  'ramlila maidan',
#  'expectation',
#  'love',
#  'pfi',
#  'mp',
#  'gauahar',
#  'defends',
#  'asim',
#  'riaz',
#  'de',
#  'toh',
#  'ne',
#  'kiya',
#  'aur',
#  'yeh',
#  ...]

# %%
def get_top_n_words(corpus, n=None):
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in      
                   vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                       reverse=True)
    return words_freq[:n]

# %%
top_words = get_top_n_words(corpus, n=20)
top_df = pd.DataFrame(top_words)
top_df.columns=["Word", "Freq"]

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(13,8)})
g = sns.barplot(x="Word", y="Freq", data=top_df)
g.set_xticklabels(g.get_xticklabels(), rotation=30)
# Out:
# [Text(0, 0, 'india'),
#  Text(0, 0, 'news'),
#  Text(0, 0, 'delhi'),
#  Text(0, 0, 'new'),
#  Text(0, 0, 'say'),
#  Text(0, 0, 'caa'),
#  Text(0, 0, 'day'),
#  Text(0, 0, 'year'),
#  Text(0, 0, 'get'),
#  Text(0, 0, 'time'),
#  Text(0, 0, 'coronavirus'),
#  Text(0, 0, 'song'),
#  Text(0, 0, 'indian'),
#  Text(0, 0, 'bjp'),
#  Text(0, 0, 'video'),
#  Text(0, 0, 'woman'),
#  Text(0, 0, 'khan'),
#  Text(0, 0, 'case'),
#  Text(0, 0, 'pm'),
#  Text(0, 0, 'share')]

# %%
#Most frequently occuring Bi-grams
def get_top_n2_words(corpus, n=None):
    vec1 = CountVectorizer(ngram_range=(2,2),  
            max_features=2000).fit(corpus)
    bag_of_words = vec1.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     
                  vec1.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                reverse=True)
    return words_freq[:n]
top2_words = get_top_n2_words(corpus, n=20)
top2_df = pd.DataFrame(top2_words)
top2_df.columns=["Bi-gram", "Freq"]
print(top2_df)
#Barplot of most freq Bi-grams
import seaborn as sns
sns.set(rc={'figure.figsize':(13,8)})
h=sns.barplot(x="Bi-gram", y="Freq", data=top2_df)
h.set_xticklabels(h.get_xticklabels(), rotation=45)
# Out:
#              Bi-gram  Freq
# 0         india news  4526
# 1           bigg bos  4257
# 2        new zealand  3687
# 3         time india  3181
# 4            pm modi  3167
# 5         box office  3002
# 6           ali khan  2941
# 7           year old  2727
# 8          world cup  2694
# 9           anti caa  2424
# 10      donald trump  2364
# 11  deepika padukone  2206
# 12       kid nursery  2195
# 13         news time  2195
# 14          new year  2179
# 15      shaheen bagh  2168
# 16     market update  2111
# 17       virat kohli  2096
# 18     nursery rhyme  2048
# 19        tamil nadu  1993
# [Text(0, 0, 'india news'),
#  Text(0, 0, 'bigg bos'),
#  Text(0, 0, 'new zealand'),
#  Text(0, 0, 'time india'),
#  Text(0, 0, 'pm modi'),
#  Text(0, 0, 'box office'),
#  Text(0, 0, 'ali khan'),
#  Text(0, 0, 'year old'),
#  Text(0, 0, 'world cup'),
#  Text(0, 0, 'anti caa'),
#  Text(0, 0, 'donald trump'),
#  Text(0, 0, 'deepika padukone'),
#  Text(0, 0, 'kid nursery'),
#  Text(0, 0, 'news time'),
#  Text(0, 0, 'new year'),
#  Text(0, 0, 'shaheen bagh'),
#  Text(0, 0, 'market update'),
#  Text(0, 0, 'virat kohli'),
#  Text(0, 0, 'nursery rhyme'),
#  Text(0, 0, 'tamil nadu')]

# %%
#Most frequently occuring Tri-grams
def get_top_n3_words(corpus, n=None):
    vec1 = CountVectorizer(ngram_range=(3,3), 
           max_features=2000).fit(corpus)
    bag_of_words = vec1.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     
                  vec1.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                reverse=True)
    return words_freq[:n]
top3_words = get_top_n3_words(corpus, n=20)
top3_df = pd.DataFrame(top3_words)
top3_df.columns=["Tri-gram", "Freq"]
print(top3_df)
#Barplot of most freq Tri-grams
import seaborn as sns
sns.set(rc={'figure.figsize':(13,8)})
j=sns.barplot(x="Tri-gram", y="Freq", data=top3_df)
j.set_xticklabels(j.get_xticklabels(), rotation=45)
# Out:
#                    Tri-gram  Freq
# 0           news time india  2185
# 1             sara ali khan  1800
# 2       share market update  1639
# 3         kid nursery story  1443
# 4        nursery rhyme baby  1338
# 5           rhyme baby song  1338
# 6              love aaj kal  1163
# 7     box office collection  1046
# 8      latest bhojpuri song  1030
# 9       story nursery rhyme   987
# 10        kid story nursery   969
# 11         anti caa protest   917
# 12      latest punjabi song   894
# 13        india new zealand   892
# 14           shah rukh khan   854
# 15        new zealand india   849
# 16  delhi assembly election   848
# 17            saif ali khan   819
# 18    office collection day   723
# 19      fantasy cricket tip   693
# [Text(0, 0, 'news time india'),
#  Text(0, 0, 'sara ali khan'),
#  Text(0, 0, 'share market update'),
#  Text(0, 0, 'kid nursery story'),
#  Text(0, 0, 'nursery rhyme baby'),
#  Text(0, 0, 'rhyme baby song'),
#  Text(0, 0, 'love aaj kal'),
#  Text(0, 0, 'box office collection'),
#  Text(0, 0, 'latest bhojpuri song'),
#  Text(0, 0, 'story nursery rhyme'),
#  Text(0, 0, 'kid story nursery'),
#  Text(0, 0, 'anti caa protest'),
#  Text(0, 0, 'latest punjabi song'),
#  Text(0, 0, 'india new zealand'),
#  Text(0, 0, 'shah rukh khan'),
#  Text(0, 0, 'new zealand india'),
#  Text(0, 0, 'delhi assembly election'),
#  Text(0, 0, 'saif ali khan'),
#  Text(0, 0, 'office collection day'),
#  Text(0, 0, 'fantasy cricket tip')]

# %%
from sklearn.feature_extraction.text import TfidfTransformer
 
tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)
tfidf_transformer.fit(X)
# get feature names
feature_names=cv.get_feature_names()
 
# fetch document for which keywords needs to be extracted
doc=corpus[222]
 
#generate tf-idf for the given document
tf_idf_vector=tfidf_transformer.transform(cv.transform([doc]))

# %%
#Function for sorting tf_idf in descending order
from scipy.sparse import coo_matrix
def sort_coo(coo_matrix):
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)
 
def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    """get the feature names and tf-idf score of top n items"""
    
    #use only topn items from vector
    sorted_items = sorted_items[:topn]
 
    score_vals = []
    feature_vals = []
    
    # word index and corresponding tf-idf score
    for idx, score in sorted_items:
        
        #keep track of feature name and its corresponding score
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])
 
    #create a tuples of feature,score
    #results = zip(feature_vals,score_vals)
    results= {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]]=score_vals[idx]
    
    return results
#sort the tf-idf vectors by descending order of scores
sorted_items=sort_coo(tf_idf_vector.tocoo())
#extract only the top n; n here is 10
keywords=extract_topn_from_vector(feature_names,sorted_items,5)
 
# now print the results
print("\nAbstract:")
print(doc)
print("\nKeywords:")
for k in keywords:
    print(k,keywords[k])
# Out:
# Abstract:
# plantation company want export scheme extended
#
# Keywords:
# extended 0.522
# export 0.465
# scheme 0.441
# company 0.411
# want 0.384

# %%
from langdetect import detect

# %%
from polyglot.detect import Detector

mixed_text = u"""
China (simplified Chinese: 中国; traditional Chinese: 中國),
officially the People's Republic of China (PRC), is a sovereign state
located in East Asia.
"""
for language in Detector(mixed_text).languages:
        print(language)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-a3a69cf15772> in <module>
# ----> 1 from polyglot.detect import Detector
#       2
#       3 mixed_text = u"""
#       4 China (simplified Chinese: 中国; traditional Chinese: 中國),
#       5 officially the People's Republic of China (PRC), is a sovereign state
#
# ModuleNotFoundError: No module named 'polyglot'
